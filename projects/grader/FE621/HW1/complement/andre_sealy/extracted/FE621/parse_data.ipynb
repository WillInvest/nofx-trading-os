# %%
import pandas as pd

# %%
df = pd.read_csv('data2.csv')
df.head()
# Out:
#        contractSymbol              lastTradeDate  strike  lastPrice     bid  \
# 0  SPY260220C00335000  2026-02-02 19:44:19+00:00   335.0     362.17  351.50
# 1  SPY260220C00345000  2026-02-02 14:42:12+00:00   345.0     348.01  340.97
# 2  SPY260220C00350000  2026-02-03 19:25:15+00:00   350.0     337.41  335.88
# 3  SPY260220C00365000  2025-11-26 15:41:15+00:00   365.0     316.48  325.28
# 4  SPY260220C00370000  2025-11-20 17:07:06+00:00   370.0     292.80  320.42
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  354.26     0.0            0.0     1.0             3           1.510745
# 1  343.78     0.0            0.0     2.0             2           1.691652
# 2  339.21     0.0            0.0     7.0            12           1.232426
# 3  328.67     0.0            0.0     2.0             2           1.953369
# 4  323.70     0.0            0.0     NaN             1           1.924683
#
#    inTheMoney contractSize currency expirationDate
# ...

# %%
mask_p_after_9 = df["contractSymbol"].str.contains(r"^.{9}P", regex=True, na=False)
df_put = df[mask_p_after_9]

df['option_type'] = mask_p_after_9
df.head()
# Out:
#        contractSymbol              lastTradeDate  strike  lastPrice     bid  \
# 0  SPY260220C00335000  2026-02-02 19:44:19+00:00   335.0     362.17  351.50
# 1  SPY260220C00345000  2026-02-02 14:42:12+00:00   345.0     348.01  340.97
# 2  SPY260220C00350000  2026-02-03 19:25:15+00:00   350.0     337.41  335.88
# 3  SPY260220C00365000  2025-11-26 15:41:15+00:00   365.0     316.48  325.28
# 4  SPY260220C00370000  2025-11-20 17:07:06+00:00   370.0     292.80  320.42
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  354.26     0.0            0.0     1.0             3           1.510745
# 1  343.78     0.0            0.0     2.0             2           1.691652
# 2  339.21     0.0            0.0     7.0            12           1.232426
# 3  328.67     0.0            0.0     2.0             2           1.953369
# 4  323.70     0.0            0.0     NaN             1           1.924683
#
#    inTheMoney contractSize currency expirationDate  option_type
# ...

# %%
df['option_type'] = df['option_type'].map({False: 'C', True: 'P'})

# %%
df.to_csv('data2.csv', index=False)

# %%
df.to_csv('data1.csv', index=False)
